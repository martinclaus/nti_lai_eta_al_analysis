# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from cartopy.mpl.ticker import LongitudeFormatter,LatitudeFormatter

# %%
ds = xr.open_zarr('data_fig1.zarr')

# %%
width = 95*0.0393700787
fig = plt.figure(figsize=(width,5.2))
plt.rcParams['font.size'] =8

from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})

ax1 = fig.add_subplot(211)


lon = ds.lon  
line1, = ax1.plot(lon,ds.var_SST,label='SST')
line2, = ax1.plot(lon,ds.var_NTI,label='NEMO-NTI')
line3, = ax1.plot(lon,ds.var_SSTmD20,label='SSTmD20')
ax1.set_xlim(140,260)
ax1.set_ylim(0,2)
ax1.set_yticks(np.arange(0,2.25,0.25))  #(0,3.5,0.5)    
plt.legend((line1,line2,line3),('SST','NEMO-NTI','SSTmD20'),loc=2)   
ax1.set_ylabel(""); #℃
ax1.set_xlabel('longitude');
ax1.xaxis.set_major_formatter(LongitudeFormatter())
ax1.grid(color='grey',linestyle = ':',axis='y')


ax2 = ax1.twinx()
line4, = ax2.plot(lon,ds.var_D20,label='D20',color='mediumpurple', linestyle='--')
ax2.set_yticks(np.arange(0,450,50))
ax2.set_ylabel("m$^{2}$");
ax2.set_title('')
ax2.spines['bottom'].set_position(('data', 0))
plt.legend(loc=1)
plt.title('(a) Variance along equator',loc='left') # loc='left',y=0.88


ax3 = fig.add_subplot(212)
ds.corr_d20_sst.plot(label='D20',color='mediumpurple', linestyle='--')
ds.corr_nti_sst.plot(label='NEMO-NTI',color='C1')
ds.corr_sstmd20_sst.plot(label='SSTmD20',color='C2')
ax3.xaxis.set_major_formatter(LongitudeFormatter())
plt.xlim(140,260)
plt.ylim(-1,1.1)
plt.legend();
plt.ylabel("");
plt.xlabel('longitude');
plt.title('(b) Correlation with SST',loc='left') #,y=0.1,loc='left'
plt.title('')
plt.axhline(y=0., c="0.5", ls=":", lw=3)
plt.grid(color='grey',linestyle = ':',axis='y')
plt.subplots_adjust(wspace =0, hspace = 0.4)
plt.fill_between(lon,-0.25,0.25,color='0.5',alpha=0.3)
plt.savefig("fig1.pdf", format="pdf", bbox_inches="tight")
plt.show()
