# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %%
ds_var = xr.open_zarr('data_fig5.zarr/')

# %%
width = 95*0.0393700787
fig = plt.figure(figsize=(width,2.6))
plt.rcParams['font.size'] =8
from matplotlib import rc
ax1 = fig.add_subplot(111)
time = ds_var.time
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
line1, = ax1.plot(time,ds_var.n4_var ,label='NEMO-SST',c='#482677FF');
line2, = ax1.plot(time,ds_var.h_n4_var,label='Hadley-SST',c='#2D708EFF');
line3, = ax1.plot(time,ds_var.iwp_var,label='$\mathregular{N_{wp}}$',c='#FDE725FF');
line4, = ax1.plot(time,ds_var.emi_var,label='EMI',c='#55C667FF');
ax1.set_ylim(0,1)
ax1.set_yticks(np.arange(0,1.0,0.2))  #(0,3.5,0.5)    
plt.legend((line1,line2,line3,line4),('SST','NEMO-NTI','Nwp','EMI'),loc=2)   
ax1.set_ylabel("$^\circ$C $^{2}$"); 
ax1.set_xlabel('time');
ax1.grid(color='grey',linestyle = ':',axis='y')
plt.legend(handles=[line1,line2,line4,line3],loc=2)

ax2 = ax1.twinx()
line5, = ax2.plot(time,ds_var.nlti_var,label='$\mathregular{\eta_{nlti}}$',color='C1', linestyle='--')
ax2.set_yticks(np.arange(0,0.0024,0.0004))
ax2.set_ylabel("m$^{2}$");
ax2.set_title('')
ax2.spines['bottom'].set_position(('data', 0))
plt.legend(loc=1)


plt.xlabel('time')
plt.title("21-yr running variance",loc='left');
plt.title('')
plt.grid(color='grey',linestyle = ':',axis='y')

plt.savefig("fig5.pdf", format="pdf", bbox_inches="tight")
plt.show()
