# %%
import xarray as xr
import matplotlib.pyplot as plt
from cartopy.mpl.ticker import LongitudeFormatter,LatitudeFormatter
import matplotlib.dates as mdates

# %%
ds = xr.open_zarr('data_fig3S.zarr')

# %%
width = 190*0.0393700787
fig = plt.figure(figsize=(width,5.5))
plt.rcParams['font.size'] =8
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})

ax1 = fig.add_subplot(131)
ax1.xaxis.set_major_formatter(LongitudeFormatter())
ds.sshne.rename('').plot(vmin=-0.3, vmax=0.3,cmap=plt.cm.RdBu_r,extend='both',rasterized=True)
year =  mdates.YearLocator(5,month=1) 
ax1.yaxis.set_major_locator(year)   
ax1.yaxis.set_major_formatter(mdates.DateFormatter('%Y')) # %Y-%m
plt.title("(a) SSH_NEMO",loc='left');
plt.title('');
plt.ylabel("time");
plt.xlabel('longitude');

ax2 = fig.add_subplot(132)
ax2.xaxis.set_major_formatter(LongitudeFormatter())
ds.d20ne.rename('').plot(vmin=-80, vmax=80,cmap=plt.cm.RdBu_r,extend='both',rasterized=True)
ax2.yaxis.set_major_locator(year)   
ax2.yaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.title("(b) D20_NEMO",loc='left');
plt.title('');
plt.ylabel("");
plt.xlabel('longitude');

ax3 = fig.add_subplot(133)
ax3.xaxis.set_major_formatter(LongitudeFormatter())
ds.sshli.rename('').plot(vmin=-0.3, vmax=0.3,cmap=plt.cm.RdBu_r,extend='both',rasterized=True) 
ax3.yaxis.set_major_locator(year)   
ax3.yaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.title("(c) SSH_Linear",loc='left');
plt.title('');
plt.ylabel("");
plt.xlabel('longitude');

# plt.subplots_adjust(wspace =0.5, hspace = 0)
plt.tight_layout()
plt.savefig("figS3.pdf", format="pdf", bbox_inches="tight")
plt.show()
