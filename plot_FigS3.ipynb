# %%
import xarray as xr
import matplotlib.pyplot as plt
from cartopy.mpl.ticker import LongitudeFormatter,LatitudeFormatter

# %%
ds = xr.open_zarr('data_figS3.zarr/')

# %%
fig = plt.figure(figsize=(5.5,5.5))
plt.rcParams['font.size'] =8
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})

ax1 = fig.add_subplot(211)
ax1.xaxis.set_major_formatter(LongitudeFormatter())
ax1.yaxis.set_major_formatter(LatitudeFormatter())
xr.corr(ds.ssh_nemo,ds.ssh_lin,dim='time').plot(vmin=0,vmax=1, rasterized=True)
plt.title("(a) Correlation between linear SSH and NEMO SSH",loc='left')
plt.title('')
plt.grid(color='grey',linestyle = ':')
plt.ylabel("latitude");
plt.xlabel('longitude');

ax2 = fig.add_subplot(212)
ax2.xaxis.set_major_formatter(LongitudeFormatter())
ax2.yaxis.set_major_formatter(LatitudeFormatter())
xr.corr(ds.ssh_lin,ds.d20_nemo,dim='time').plot(vmin= 0,vmax=1, rasterized=True) #,cmap=plt.cm.YlOrBr
plt.title("(b) Correlation between linear SSH and NEMO D20",loc='left')
plt.title('')
plt.ylabel("latitude");
plt.xlabel('longitude');

plt.grid(color='grey',linestyle = ':')
plt.subplots_adjust(wspace =0, hspace = 0.35)
plt.savefig("figS3.pdf", format="pdf", bbox_inches="tight")
plt.show()
# Out:
# /home/jufen.lai/miniconda3/envs/work/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jufen.lai/miniconda3/envs/work/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
