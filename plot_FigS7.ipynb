# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from cartopy.mpl.ticker import LongitudeFormatter,LatitudeFormatter
import matplotlib.dates as mdates

# %%
ds = xr.open_zarr('data_figS7.zarr/')

# %%
width = 95*0.0393700787
fig = plt.figure(figsize=(width, 5.5))
plt.rcParams['font.size'] =8

from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})

ax1 = fig.add_subplot(111)
ax1.xaxis.set_major_formatter(LongitudeFormatter())
ds.slope.plot(
    vmin=0.0025, vmax=0.0045, cmap=plt.cm.YlOrBr,
    cbar_kwargs={'label': ''},
    rasterized=True
) 
plt.title("Regression(D20,SSH)",loc='left')
plt.title('')
plt.xlim(140, 260)
plt.ylabel("time");
plt.xlabel('longitude');
plt.grid(color='grey',linestyle = ':')

plt.savefig("figS7.pdf", format="pdf", bbox_inches="tight")
plt.show()
